# %% [markdown]
# # Agroparistech Data

# %%
import glob
import sys
from pyprojroot import here

sys.path.insert(0, "../../src")
from run_mp import *
from utilities import *

# %% [markdown]
# ## Clean QGIS Extraction

# %%
import sys

sys.path.insert(0, "../../src")
from imports import *

init_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get all extracated files
files = glob.glob("../../data/agroparistech-intern/zonal_statistics/qgis/*.csv")
filenames = [f.split("output_")[-1].split("-e")[0] for f in files]

# Get structure of df
df_all = pd.read_csv(files[0])[["idp", "first_year"]]

# Loop through all files and attach to them by idp and first year
for i in range(len(files)):
    df = pd.read_csv(files[i]).rename(
        columns={
            "_mean": filenames[i],
        }
    )
    df_all = pd.merge(df_all, df, on=["idp", "first_year"], how="left")

# Clean up failed files and fix names (files with 'lor' in name were only for Vosges region)
df_all = df_all.rename(
    columns={
        "cn_ess2_L93": "soil_CN",
        "ph_ess2_L93": "soil_pH",
        "ep_ess2_fr": "soil_waterlogging_perm",
        "et_ess2_Fr": "soil_waterlogging_temp",
        "rum2018_L93": "soil_swhc",
    }
)[
    [
        "idp",
        "first_year",
        "soil_CN",
        "soil_pH",
        "soil_waterlogging_perm",
        "soil_waterlogging_temp",
        "soil_swhc",
    ]
]


df_all
# Out:
#            idp  first_year    soil_CN   soil_pH  soil_waterlogging_perm  \
# 0       500008        2010  14.794831  5.099068               -0.003777
# 1       500013        2010  21.828443  4.849116               -0.013355
# 2       500098        2010  13.093917  7.724813               -0.018405
# 3       500103        2010  11.041480  6.258320                0.022226
# 4       500137        2010  23.001508  3.653516               -0.010318
# ...        ...         ...        ...       ...                     ...
# 51408  1354883        2018  20.588218  4.670717                0.005196
# 51409  1354893        2018  15.910927  5.986784               -0.019251
# 51410  1354907        2018  22.625124  4.700046               -0.012818
# 51411  1354911        2018  12.702960  6.219271               -0.007208
# 51412  1354913        2018  15.566992  5.665725               -0.013618
#
#        soil_waterlogging_temp   soil_swhc
# 0                    0.040083   97.514820
# 1                    0.036842   46.959372
# 2                   -0.028902   49.687280
# 3                    0.040558   94.365169
# 4                    0.024519   82.437725
# ...                       ...         ...
# 51408                0.014559   31.184496
# 51409                0.020064   54.702627
# 51410                0.030401   77.770641
# 51411                0.041488  108.020103
# 51412                0.027004   70.903442
#
# [51413 rows x 7 columns]

# %%
df_all.to_feather("../../data/final/predictor_datasets/soil.feather")
